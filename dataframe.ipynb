# %%
import pandas as pd
df=pd.read_csv("data.csv")
#print(df)
df.shape
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
rows,columns=df.shape
rows
# Out:
# 198

# %%
columns
# Out:
# 127

# %%
df.head(5)
# Out:
#     Unnamed: 0                                               2016  \
# 0          NaN  Prevalence of obesity among adults, BMI &Great...
# 1          NaN                                         18+  years
# 2      Country                                         Both sexes
# 3  Afghanistan                                      5.5 [3.4-8.1]
# 4      Albania                                   21.7 [17.0-26.7]
#
#                                               2016.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      3.2 [1.3-6.4]
# 4                                   21.6 [14.8-29.0]
#
#                                               2016.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                     7.6 [4.3-12.4]
# 4                                   21.8 [15.3-28.9]
#
#                                                 2015  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      5.2 [3.3-7.7]
# 4                                   21.1 [16.6-26.0]
#
#                                               2015.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      3.0 [1.3-6.0]
# 4                                   20.9 [14.4-28.1]
#
#                                               2015.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                     7.3 [4.1-11.8]
# 4                                   21.3 [15.1-28.1]
#
#                                                 2014  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      4.9 [3.1-7.3]
# 4                                   20.5 [16.2-25.1]
#
#                                               2014.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      2.8 [1.2-5.6]
# 4                                   20.2 [13.9-27.3]
#
#                                               2014.2  ...  \
# 0  Prevalence of obesity among adults, BMI &Great...  ...
# 1                                         18+  years  ...
# 2                                             Female  ...
# 3                                     7.0 [4.0-11.3]  ...
# 4                                   20.8 [14.9-27.4]  ...
#
#                                               1978.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                      0.9 [0.3-2.2]
# 4                                     9.1 [4.6-15.5]
#
#                                                 1977  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      0.6 [0.2-1.2]
# 4                                     6.8 [4.0-10.7]
#
#                                               1977.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      0.2 [0.0-0.7]
# 4                                      4.8 [2.0-9.3]
#
#                                               1977.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                      0.9 [0.3-2.1]
# 4                                     8.9 [4.3-15.4]
#
#                                                 1976  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      0.5 [0.2-1.1]
# 4                                     6.7 [3.8-10.6]
#
#                                               1976.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      0.2 [0.0-0.7]
# 4                                      4.6 [1.8-9.2]
#
#                                               1976.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                      0.8 [0.2-2.0]
# 4                                     8.8 [4.1-15.4]
#
#                                                 1975  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      0.5 [0.2-1.1]
# 4                                     6.5 [3.6-10.5]
#
#                                               1975.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      0.2 [0.0-0.6]
# 4                                      4.4 [1.7-9.2]
#
#                                               1975.2
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                      0.8 [0.2-2.0]
# 4                                     8.6 [3.9-15.4]
#
# [5 rows x 127 columns]

# %%
df.tail(2)
# Out:
#     Unnamed: 0              2016         2016.1            2016.2  \
# 196     Zambia    8.1 [5.8-10.7]  3.6 [1.7-6.5]   12.4 [8.5-17.1]
# 197   Zimbabwe  15.5 [12.0-19.2]  4.7 [2.5-8.0]  25.3 [19.1-32.0]
#
#                  2015         2015.1            2015.2              2014  \
# 196    7.7 [5.6-10.2]  3.4 [1.6-6.1]   12.0 [8.2-16.4]     7.4 [5.4-9.8]
# 197  15.2 [11.9-18.8]  4.5 [2.4-7.6]  24.8 [18.9-31.3]  14.9 [11.7-18.4]
#
#             2014.1            2014.2  ...          1978.2           1977  \
# 196  3.2 [1.5-5.7]   11.5 [7.9-15.7]  ...   3.0 [1.3-5.6]  1.7 [0.8-3.2]
# 197  4.4 [2.4-7.3]  24.4 [18.8-30.6]  ...  7.7 [3.9-13.1]  4.0 [2.1-6.8]
#
#             1977.1          1977.2           1976         1976.1  \
# 196  0.5 [0.1-1.5]   2.9 [1.2-5.4]  1.6 [0.7-3.1]  0.5 [0.1-1.4]
# 197  0.5 [0.1-1.3]  7.4 [3.6-12.7]  3.9 [1.9-6.7]  0.5 [0.1-1.3]
#
#              1976.2           1975         1975.1          1975.2
# 196   2.7 [1.1-5.3]  1.5 [0.7-3.0]  0.5 [0.1-1.4]   2.5 [1.0-5.1]
# 197  7.0 [3.3-12.4]  3.7 [1.7-6.5]  0.4 [0.1-1.3]  6.7 [3.0-12.2]
#
# [2 rows x 127 columns]

# %%
df[2:5]
# Out:
#     Unnamed: 0              2016            2016.1            2016.2  \
# 2      Country        Both sexes              Male            Female
# 3  Afghanistan     5.5 [3.4-8.1]     3.2 [1.3-6.4]    7.6 [4.3-12.4]
# 4      Albania  21.7 [17.0-26.7]  21.6 [14.8-29.0]  21.8 [15.3-28.9]
#
#                2015            2015.1            2015.2              2014  \
# 2        Both sexes              Male            Female        Both sexes
# 3     5.2 [3.3-7.7]     3.0 [1.3-6.0]    7.3 [4.1-11.8]     4.9 [3.1-7.3]
# 4  21.1 [16.6-26.0]  20.9 [14.4-28.1]  21.3 [15.1-28.1]  20.5 [16.2-25.1]
#
#              2014.1            2014.2  ...          1978.2            1977  \
# 2              Male            Female  ...          Female      Both sexes
# 3     2.8 [1.2-5.6]    7.0 [4.0-11.3]  ...   0.9 [0.3-2.2]   0.6 [0.2-1.2]
# 4  20.2 [13.9-27.3]  20.8 [14.9-27.4]  ...  9.1 [4.6-15.5]  6.8 [4.0-10.7]
#
#           1977.1          1977.2            1976         1976.1  \
# 2           Male          Female      Both sexes           Male
# 3  0.2 [0.0-0.7]   0.9 [0.3-2.1]   0.5 [0.2-1.1]  0.2 [0.0-0.7]
# 4  4.8 [2.0-9.3]  8.9 [4.3-15.4]  6.7 [3.8-10.6]  4.6 [1.8-9.2]
#
#            1976.2            1975         1975.1          1975.2
# 2          Female      Both sexes           Male          Female
# 3   0.8 [0.2-2.0]   0.5 [0.2-1.1]  0.2 [0.0-0.6]   0.8 [0.2-2.0]
# 4  8.8 [4.1-15.4]  6.5 [3.6-10.5]  4.4 [1.7-9.2]  8.6 [3.9-15.4]
#
# [3 rows x 127 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '2016', '2016.1', '2016.2', '2015', '2015.1', '2015.2',
#        '2014', '2014.1', '2014.2',
#        ...
#        '1978.2', '1977', '1977.1', '1977.2', '1976', '1976.1', '1976.2',
#        '1975', '1975.1', '1975.2'],
#       dtype='object', length=127)

# %%
df.describe()
# Out:
#        Unnamed: 0     2016   2016.1   2016.2     2015   2015.1   2015.2  \
# count         196      198      198      198      198      198      198
# unique        196      192      195      195      194      194      195
# top      Portugal  No data  No data  No data  No data  No data  No data
# freq            1        4        4        4        4        4        4
#
#            2014   2014.1   2014.2  ...   1978.2     1977         1977.1  \
# count       198      198      198  ...      198      198            198
# unique      194      193      194  ...      192      184            164
# top     No data  No data  No data  ...  No data  No data  0.2 [0.0-0.7]
# freq          4        4        4  ...        4        4              6
#
#          1977.2     1976         1976.1   1976.2           1975  \
# count       198      198            198      198            198
# unique      185      183            161      190            177
# top     No data  No data  0.2 [0.0-0.7]  No data  0.9 [0.4-1.8]
# freq          4        4              7        4              4
#
#                1975.1   1975.2
# count             198      198
# unique            155      185
# top     0.4 [0.1-1.2]  No data
# freq                7        4
#
# [4 rows x 127 columns]

# %%
import pandas as pd
df=pd.read_csv("data.csv")
#print(df)
rows,columns=df.shape
rows
columns
# Out:
# 4

# %%
df.head(2)
# Out:
#            day                    event           temprature        windspeed
# 0    01/02/2020                    rain                   23              123
# 1  02/02/2019                     sunny                   23               12

# %%
df.tail(2)
# Out:
#          day                    event           temprature        windspeed
# 3  03/07/2087                    rain                   13               11
# 4  02/08/2030                    hoty                   67               12

# %%
df[2:5]
# Out:
#          day                    event           temprature        windspeed
# 2   04/9/2098                    cool                   12               23
# 3  03/07/2087                    rain                   13               11
# 4  02/08/2030                    hoty                   67               12

# %%
df.columns
# Out:
# Index(['day ', '                  event', '         temprature',
#        '      windspeed'],
#       dtype='object')

# %%
import pandas as pd 
  
# Define a dictionary containing employee data 
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
  
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data) 
df
# select two columns 
#print(df[['Name', 'Qualification']])
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %%
print(df[['Name','Age']])
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   32

# %%
print(df[['Name']])
# Out:
#      Name
# 0     Jai
# 1  Princi
# 2  Gaurav
# 3    Anuj

# %%
df['Age'].max()
df['Age'].min()
df['Age'].mean()
# Out:
# 26.25

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   26.250000
# std     4.349329
# min    22.000000
# 25%    23.500000
# 50%    25.500000
# 75%    28.250000
# max    32.000000

# %%
df[df.Age==df.Age.max()]
# Out:
#    Name  Age  Address Qualification
# 3  Anuj   32  Kannauj           Phd

# %%
df.Age
# Out:
# 0    27
# 1    24
# 2    22
# 3    32
# Name: Age, dtype: int64

# %%
df.Age.max()
# Out:
# 32

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.set_index('Age',inplace=True)
df
# Out:
#        Name    Address Qualification
# Age
# 27      Jai      Delhi           Msc
# 24   Princi     Kanpur            MA
# 22   Gaurav  Allahabad           MCA
# 32     Anuj    Kannauj           Phd

# %%
df.reset_index(inplace=True)
df
# Out:
#    Age    Name    Address Qualification
# 0   27     Jai      Delhi           Msc
# 1   24  Princi     Kanpur            MA
# 2   22  Gaurav  Allahabad           MCA
# 3   32    Anuj    Kannauj           Phd

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    Age    Name    Address Qualification
# 0   27     Jai      Delhi           Msc
# 1   24  Princi     Kanpur            MA
# 2   22  Gaurav  Allahabad           MCA
# 3   32    Anuj    Kannauj           Phd>
